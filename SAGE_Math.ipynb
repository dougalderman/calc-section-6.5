# %%
#Problem 1

# %%
x = var('x')

# %%
y = var('y')

# %%
lam = var('lam')

# %%
def f(x, y): return x*y

# %%
x

# %%
h = g(x, y) == 0

# %%
def i(x): return 10 - 3*x

# %%
h
# Out:
# 3*x + y - 10 == 0

# %%
p = []

# %%
p.append(plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8))

# %%
p.append(plot3d(g,(x,-5,5),(y,-5,5),color='red',opacity=0.8))

# %%
sum(p)
# Out:
# Graphics3d Object

# %%
q = []

# %%
q.append(plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8))

# %%
q.append(plot3d(h,(x,-5,5),(y,-5,5),color='red',opacity=0.8))

# %%
sum(q)
# Out:
# Graphics3d Object

# %%
r = []

# %%
r.append(plot3d(g,(x,-5,5),(y,-5,5),color='blue',opacity=0.8))

# %%
r.append(plot3d(h,(x,-5,5),(y,-5,5),color='red',opacity=0.8))

# %%
sum(r)
# Out:
# Graphics3d Object

# %%
s = []

# %%
s.append(plot(i,(x,-5,5),color='blue'))

# %%
sum(s)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def F(x, y, lam): return f(x, y) - lam*(g(x, y))

# %%
Fx = diff(F(x, y, lam), x, 1)

# %%
Fx
# Out:
# -3*lam + y

# %%
Fy = diff(F(x, y, lam), y, 1)

# %%
Fy
# Out:
# -lam + x

# %%
Flam = diff(F(x, y, lam), lam, 1)

# %%
Flam
# Out:
# -3*x - y + 10

# %%
solve([Fx==0, Fy==0, Flam==0], x, y, lam)
# Out:
# [[x == (5/3), y == 5, lam == (5/3)]]

# %%
f(5/3, 5)
# Out:
# 25/3

# %% [markdown]
# ---

# %%
#Problem 5

# %%
x = var('x')

# %%
y = var('y')

# %%
lam = var('lam')

# %%
def f(x, y): return x^2 + y^2

# %%
def g(x, y): return 2*x + y - 10

# %%
def h(x): return 10 - 2*x

# %%
p = []

# %%
p.append(plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8))

# %%
p.append(plot3d(g,(x,-5,5),(y,-5,5),color='red',opacity=0.8))

# %%
sum(p)
# Out:
# Graphics3d Object

# %%
def F(x, y, lam): return f(x, y) - lam*(g(x, y))

# %%
Fx = diff(F(x, y, lam), x, 1)

# %%
Fx
# Out:
# -2*lam + 2*x

# %%
Fy = diff(F(x, y, lam), y, 1)

# %%
Fy
# Out:
# -lam + 2*y

# %%
Flam = diff(F(x, y, lam), lam, 1)

# %%
Flam
# Out:
# -2*x - y + 10

# %%
solve([Fx==0, Fy==0, Flam==0], x, y, lam)
# Out:
# [[x == 4, y == 2, lam == 4]]

# %%
f(4, 2)
# Out:
# 20

# %% [markdown]
# ---

# %%
#Problem 9

# %%
x = var('x')

# %%
y = var('y')

# %%
z = var('z')

# %%
lam = var('lam')

# %%
def f(x, y, z): return x^2 + y^2 + z^2

# %%
def g(x, y, z): return y + 2*x - z - 3

# %%
def F(x, y, z, lam): return f(x, y, z) - lam*(g(x, y, z))

# %%
Fx = diff(F(x, y, z, lam), x, 1)

# %%
Fx
# Out:
# -2*lam + 2*x

# %%
Fy = diff(F(x, y, z, lam), y, 1)

# %%
Fy
# Out:
# -lam + 2*y

# %%
Fz = diff(F(x, y, z, lam), z, 1)

# %%
Fz
# Out:
# lam + 2*z

# %%
Flam = diff(F(x, y, z, lam), lam, 1)

# %%
Flam
# Out:
# -2*x - y + z + 3

# %%
solve([Fx==0, Fy==0, Fz==0, Flam==0], x, y, z, lam)
# Out:
# [[x == 1, y == (1/2), z == (-1/2), lam == 1]]

# %%
f(1, 1/2, -1/2)
# Out:
# 3/2

# %% [markdown]
# ---

# %%
#Problem 29

# %%
x = var('x')

# %%
y = var('y')

# %%
z = var('z')

# %%
lam = var('lam')

# %%
def f(x, y, z): return x^2*y^2*z^2

# %%
def g(x, y, z): return x^2 + y^2 + z^2 - 2

# %%
implicit_plot3d(f, (x,-5,5), (y,-5,5), (z,-5,5), color='blue')
# Out:
# Graphics3d Object

# %%
def F(x, y, z, lam): return f(x, y, z) - lam*(g(x, y, z))

# %%
Fx = diff(F(x, y, z, lam), x, 1)

# %%
Fx
# Out:
# 2*x*y^2*z^2 - 2*lam*x

# %%
Fy = diff(F(x, y, z, lam), y, 1)

# %%
Fy
# Out:
# 2*x^2*y*z^2 - 2*lam*y

# %%
Fz = diff(F(x, y, z, lam), z, 1)

# %%
Fz
# Out:
# 2*x^2*y^2*z - 2*lam*z

# %%
Flam = diff(F(x, y, z, lam), lam, 1)

# %%
Flam
# Out:
# -x^2 - y^2 - z^2 + 2

# %%
solve([Fx==0, Fy==0, Fz==0, Flam==0], x, y, z, lam)
# Out:
# [[x == r1, y == sqrt(-r1^2 + 2), z == 0, lam == 0], [x == r2, y == -sqrt(-r2^2 + 2), z == 0, lam == 0], [x == r3, y == 0, z == sqrt(-r3^2 + 2), lam == 0], [x == r4, y == 0, z == -sqrt(-r4^2 + 2), lam == 0], [x == 0, y == r5, z == sqrt(-r5^2 + 2), lam == 0], [x == 0, y == r6, z == -sqrt(-r6^2 + 2), lam == 0], [x == -sqrt(2), y == 0, z == 0, lam == 0], [x == sqrt(2), y == 0, z == 0, lam == 0], [x == 0, y == -sqrt(2), z == 0, lam == 0], [x == 0, y == sqrt(2), z == 0, lam == 0], [x == -1, y == -1, z == 0, lam == 0], [x == 1, y == 1, z == 0, lam == 0], [x == -1, y == 1, z == 0, lam == 0], [x == 1, y == -1, z == 0, lam == 0], [x == 0, y == 0, z == -sqrt(2), lam == 0], [x == 0, y == 0, z == sqrt(2), lam == 0], [x == -1/3*sqrt(3)*sqrt(2), y == -1/3*sqrt(3)*sqrt(2), z == -1/3*sqrt(3)*sqrt(2), lam == (4/9)], [x == 1/3*sqrt(3)*sqrt(2), y == 1/3*sqrt(3)*sqrt(2), z == 1/3*sqrt(3)*sqrt(2), lam == (4/9)], [x == -1/3*sqrt(3)*sqrt(2), y == -1/3*sqrt(3)*sqrt(2), z == 1/3*sqrt(3)*sqrt(2), lam == (4/9)]
# ...

# %%
f(1, -1, 0)
# Out:
# 0

# %%
f(-1, 1, 0)
# Out:
# 0

# %%
f(0, sqrt(2), 0)
# Out:
# 0

# %%
f(0, -sqrt(2), 0)
# Out:
# 0

# %%
f(-1/3*sqrt(3)*sqrt(2), 1/3*sqrt(3)*sqrt(2), 1/3*sqrt(3)*sqrt(2))
# Out:
# 8/27

# %%
f(1/3*sqrt(3)*sqrt(2), 1/3*sqrt(3)*sqrt(2), 1/3*sqrt(3)*sqrt(2))
# Out:
# 8/27

# %%
f(-1/3*sqrt(3)*sqrt(2), 1/3*sqrt(3)*sqrt(2), -1/3*sqrt(3)*sqrt(2))
# Out:
# 8/27
